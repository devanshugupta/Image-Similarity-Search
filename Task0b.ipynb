# %% [markdown]
# ### Implement a program which computes and prints the **inherent dimensionality** associated with each unique label of the even numbered Caltec101 images.

# %%
#Drive Mounting code
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Imports needed to run the code
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import numpy as np
from torchvision import models, transforms
from scipy.signal import convolve2d
import json
import matplotlib.pyplot as plt
import json
from scipy.special import softmax
import time
from sklearn.metrics import euclidean_distances

# %%
# dataset
dataset = torchvision.datasets.Caltech101('/content/drive/MyDrive/CSE515_Phase3/data', download = True) # Caltech101 Dataset will be downloaded in the mentioned path, if already downloaded it will not download again

# JSON file paths

fd_json_file_path = '/content/drive/MyDrive/CSE515_Phase3/feature_descriptors.json'     # path of the file used to store the data
label_image_mapping_json_file_path = '/content/drive/MyDrive/CSE515_Phase3/label_image_map.json' # path of the file used to store the label to image mapping
inherent_dimensionality_for_labels_info_json_file_path = '/content/drive/MyDrive/CSE515_Phase3/task0/inherent_dimensionality_for_labels_info_json_file_path.json' # path of the file used to store the label to image mapping
# Out:
# Files already downloaded and verified

# %%
# Function to save the data to a JSON file. If the file is not available it will create a file in the root project
def save_data_to_json(data, json_file):
    with open(json_file, 'w') as file:
        json.dump(data, file, indent=4)


# Function to load the existing data from a JSON file
def load_data_from_json(json_file):
    try:
        with open(json_file, 'r') as file:
            data = json.load(file)
    except FileNotFoundError:
        data = {}  # Initialize with an empty dictionary if the file doesn't exist
    return data

# %%
#Loading feature descriptors and Label to image mapping values from files saved during phase 2
fd_data = load_data_from_json(fd_json_file_path)
labelsWithImages = load_data_from_json(label_image_mapping_json_file_path)

# %%
#Stress function which computes the normalized difference between the original dimensions and MDS dimensions
def stress_function(original_distances, reduced_distances):
    stress = np.sqrt(((reduced_distances.ravel() - original_distances.ravel()) ** 2).sum() / ((original_distances.ravel() ** 2).sum()))
    return stress

# %%
#Applying MultiDimensional Scaling when number of dimensions is given
def MDS_with_dimension(data, num_dimensions):

    #Getting the number of images and number of dimensions in the feature
    num_images, num_features = len(data), len(data[0])
    #Initializing data in random position
    X = np.random.rand(num_images, num_dimensions)
    # Setting max number of iterations. 300 is industry standard
    max_iterations = 300

    #Computing original distances using L2-metric
    original_distances = euclidean_distances(data)
    #Replacing the 0 values in original distances with 1e-5 to avoid division by zero.
    original_distances[original_distances == 0] = 1e-5

    # Optimization loop
    for iteration in range(max_iterations):
        #Computing reduced distances using L2-metric
        reduced_distances = euclidean_distances(X)
        # Compute the current stress value
        current_stress = stress_function(original_distances, reduced_distances)
        #Stopping the MDS when the current stress is less than 0.05. i.e. loss is less than 5%
        if current_stress < 0.05:
            break
        #Replacing the 0 values in original distances with 1e-5 to avoid division by zero.
        reduced_distances[reduced_distances == 0] = 1e-5
        #Computing the weight of reduced distances with respect to original distance to perform guttman transformation
        ratio = original_distances / reduced_distances
        B = -ratio
        # Guttman Transformation
        B[np.arange(len(B)), np.arange(len(B))] += ratio.sum(axis=1)
        X = 1.0 / original_distances.shape[0] * np.dot(B, X)
        reduced_distances = np.sqrt((X**2).sum(axis=1)).sum()
    return X, current_stress, iteration + 1, num_dimensions

# %%
#Function to compute intrinsic dimensionality on a data i.e. when number of dimensions is not given
def MDS_scratch(data, num_dimensions=None):
    #When itrinsic dimensions is given we apply MDS for that dimensions
    if num_dimensions is not None:
        return MDS_with_dimension(data, num_dimensions)
    #Applying MDS on whole Data
    else:
        best_stress = None
        best_iteration = None
        inherent_dimensionality = None
        # Applying MDS for dimensions with an offset of 20
        for num_dimensions in range(1, 1000, 20):
            reduced_features, stress, iteration, num_dimensions = MDS_with_dimension(data, num_dimensions)
            #Updating the stress whenever we have a better stress
            if best_stress is None or stress < best_stress:
                # Applying MDS in the range where the stress becomes less than 0.05
                if best_stress is not None and best_stress > 0.05 and stress < 0.05:
                    for dim in range(inherent_dimensionality + 1, num_dimensions + 2):
                        # Applying MDS for each dimension in the range
                        reduced_features, stress, iteration, num_dimensions = MDS_with_dimension(data, dim)
                        # The first dimension where the stess becomes less than 0.05
                        if stress < 0.05:
                            best_stress = stress
                            best_iteration = iteration
                            inherent_dimensionality = num_dimensions
                            break
                    break
                # Updating stress and inherent_dimensionality values with the local bests
                best_stress = stress
                best_iteration = iteration
                inherent_dimensionality = num_dimensions
    return reduced_features, best_stress, best_iteration, inherent_dimensionality

# %% [markdown]
# ##### WE ARE USING MULTI DIMENSIONALITY SCALING TO FIND THE INHERENT DIMENSIONALITY OF EACH LABEL IN THE LAYER 3 VECTOR SPACE

# %%
# Applying MDS on each label with the layer 3 vector space
print("Applying MDS on each label using the layer 3 feature space")
inherent_dimensionality_data = {}
# Applying MDS on each label in the dataset
for label in labelsWithImages.keys():
  # Retrieving image Ids for the specific label
  imageids = labelsWithImages[label]
  # Retrieving layer 3 feature vectors for the image_ids in the label
  values = [fd_data[str(image_id)]['layer_3'] for image_id in imageids if str(image_id) in fd_data]
  values = np.array(values)
  # Applying MDS on the layer 3 vectors of each label
  reduced_features, best_stress, best_iteration, inherent_dimensionality = MDS_scratch(values)
  # Printing inherent dimensionality for each label
  print("The inherent dimensionality for label", label, "is: ", inherent_dimensionality, "Stress is:", best_stress)

  # Saving information related to inherent dimensionality for each label in a dictionary for future reference
  inherent_dimensionality_data[label] = {}
  inherent_dimensionality_data[label]['inherent_dimensionality'] = inherent_dimensionality
  inherent_dimensionality_data[label]['stress'] = best_stress
  inherent_dimensionality_data[label]['reduced_features'] = reduced_features.flatten().tolist()

# Saving information related to inherent dimensionality for each label in a json file for future reference
save_data_to_json(inherent_dimensionality_data, inherent_dimensionality_for_labels_info_json_file_path)
print("Data saved successfully at ", inherent_dimensionality_for_labels_info_json_file_path)
# Out:
# Applying MDS on each label using the layer 3 feature space
# The inherent dimensionality for label 0 is:  42 Stress is: 0.049983253360575804
# The inherent dimensionality for label 1 is:  36 Stress is: 0.04999230155012195
# The inherent dimensionality for label 2 is:  30 Stress is: 0.049988214148081876
# The inherent dimensionality for label 3 is:  40 Stress is: 0.049986138798274335
# The inherent dimensionality for label 4 is:  17 Stress is: 0.04999294415955246
# The inherent dimensionality for label 5 is:  46 Stress is: 0.049992344582400504
# The inherent dimensionality for label 6 is:  14 Stress is: 0.049971113117689946
# The inherent dimensionality for label 7 is:  14 Stress is: 0.04998132089434046
# The inherent dimensionality for label 8 is:  15 Stress is: 0.049990933533091295
# The inherent dimensionality for label 9 is:  16 Stress is: 0.04999733652943044
# The inherent dimensionality for label 10 is:  15 Stress is: 0.04996041250462308
# The inherent dimensionality for label 11 is:  13 Stress is: 0.049916498964964855
# The inherent dimensionality for label 12 is:  27 Stress is: 0.049994037591545366
# The inherent dimensionality for label 13 is:  19 Stress is: 0.04998954951441581
# The inherent dimensionality for label 14 is:  14 Stress is: 0.04999913108441998
# The inherent dimensionality for label 15 is:  21 Stress is: 0.04998175707487159
# The inherent dimensionality for label 16 is:  22 Stress is: 0.049989555614166105
# The inherent dimensionality for label 17 is:  17 Stress is: 0.04996159743282642
# The inherent dimensionality for label 18 is:  14 Stress is: 0.04999638994883721
# The inherent dimensionality for label 19 is:  29 Stress is: 0.049990793565235926
# The inherent dimensionality for label 20 is:  15 Stress is: 0.04998707328368851
# The inherent dimensionality for label 21 is:  17 Stress is: 0.049991705520252214
# The inherent dimensionality for label 22 is:  18 Stress is: 0.04999442484166165
# The inherent dimensionality for label 23 is:  25 Stress is: 0.04997314606278883
# The inherent dimensionality for label 24 is:  15 Stress is: 0.049992019725241144
# The inherent dimensionality for label 25 is:  19 Stress is: 0.049976975982108034
# The inherent dimensionality for label 26 is:  20 Stress is: 0.04999468189837112
# The inherent dimensionality for label 27 is:  18 Stress is: 0.049996079646652924
# The inherent dimensionality for label 28 is:  17 Stress is: 0.049985208474835965
# The inherent dimensionality for label 29 is:  17 Stress is: 0.049976298739444196
# The inherent dimensionality for label 30 is:  17 Stress is: 0.04999676689204739
# The inherent dimensionality for label 31 is:  20 Stress is: 0.04998852563156333
# The inherent dimensionality for label 32 is:  17 Stress is: 0.04997899660077531
# The inherent dimensionality for label 33 is:  18 Stress is: 0.04998920330031432
# The inherent dimensionality for label 34 is:  18 Stress is: 0.049994819854140095
# The inherent dimensionality for label 35 is:  21 Stress is: 0.04997570296860549
# The inherent dimensionality for label 36 is:  19 Stress is: 0.04997642711262939
# The inherent dimensionality for label 37 is:  17 Stress is: 0.049953131326331876
# The inherent dimensionality for label 38 is:  18 Stress is: 0.049951117431757716
# The inherent dimensionality for label 39 is:  22 Stress is: 0.04996031849005072
# The inherent dimensionality for label 40 is:  20 Stress is: 0.049973421242481234
# The inherent dimensionality for label 41 is:  19 Stress is: 0.049989668063883476
# The inherent dimensionality for label 42 is:  15 Stress is: 0.04990921806314849
# The inherent dimensionality for label 43 is:  10 Stress is: 0.0499979828114374
# The inherent dimensionality for label 44 is:  12 Stress is: 0.0499336009534234
# The inherent dimensionality for label 45 is:  16 Stress is: 0.04998910227507866
# The inherent dimensionality for label 46 is:  22 Stress is: 0.049998207603309516
# The inherent dimensionality for label 47 is:  24 Stress is: 0.049998843265518275
# The inherent dimensionality for label 48 is:  14 Stress is: 0.049995763865997404
# The inherent dimensionality for label 49 is:  16 Stress is: 0.04998902557127739
# The inherent dimensionality for label 50 is:  23 Stress is: 0.049974832341492956
# The inherent dimensionality for label 51 is:  21 Stress is: 0.049979554095318464
# The inherent dimensionality for label 52 is:  11 Stress is: 0.049978626139882534
# The inherent dimensionality for label 53 is:  18 Stress is: 0.04998646942942722
# The inherent dimensionality for label 54 is:  22 Stress is: 0.04998353281825435
# The inherent dimensionality for label 55 is:  27 Stress is: 0.0499808366122328
# The inherent dimensionality for label 56 is:  19 Stress is: 0.04999061346186699
# The inherent dimensionality for label 57 is:  21 Stress is: 0.0499867850086065
# The inherent dimensionality for label 58 is:  21 Stress is: 0.04999894387277302
# The inherent dimensionality for label 59 is:  13 Stress is: 0.04998592050699226
# The inherent dimensionality for label 60 is:  19 Stress is: 0.04997842228196372
# The inherent dimensionality for label 61 is:  14 Stress is: 0.04996691520470033
# The inherent dimensionality for label 62 is:  13 Stress is: 0.04999957472740071
# The inherent dimensionality for label 63 is:  20 Stress is: 0.049996493423099524
# The inherent dimensionality for label 64 is:  11 Stress is: 0.04999973319282487
# The inherent dimensionality for label 65 is:  21 Stress is: 0.04998943422650625
# The inherent dimensionality for label 66 is:  16 Stress is: 0.04997298307172801
# The inherent dimensionality for label 67 is:  11 Stress is: 0.04997189124570542
# The inherent dimensionality for label 68 is:  14 Stress is: 0.04998967581663747
# The inherent dimensionality for label 69 is:  15 Stress is: 0.04997182295359993
# The inherent dimensionality for label 70 is:  13 Stress is: 0.049959249215876675
# The inherent dimensionality for label 71 is:  14 Stress is: 0.04998225807200924
# The inherent dimensionality for label 72 is:  16 Stress is: 0.049935198371167513
# The inherent dimensionality for label 73 is:  12 Stress is: 0.04997508180746483
# The inherent dimensionality for label 74 is:  17 Stress is: 0.04999802016696244
# The inherent dimensionality for label 75 is:  20 Stress is: 0.0499812294474406
# The inherent dimensionality for label 76 is:  17 Stress is: 0.049981469539086644
# The inherent dimensionality for label 77 is:  16 Stress is: 0.0499974141462756
# The inherent dimensionality for label 78 is:  13 Stress is: 0.04997382100201109
# The inherent dimensionality for label 79 is:  19 Stress is: 0.049982159998208014
# The inherent dimensionality for label 80 is:  13 Stress is: 0.04999770275547254
# The inherent dimensionality for label 81 is:  19 Stress is: 0.049996114072535895
# The inherent dimensionality for label 82 is:  16 Stress is: 0.049986146049883
# The inherent dimensionality for label 83 is:  12 Stress is: 0.04999350913529431
# The inherent dimensionality for label 84 is:  16 Stress is: 0.04999450014773044
# The inherent dimensionality for label 85 is:  14 Stress is: 0.04999758084095899
# The inherent dimensionality for label 86 is:  19 Stress is: 0.049992192992724505
# The inherent dimensionality for label 87 is:  18 Stress is: 0.04995152289991793
# The inherent dimensionality for label 88 is:  15 Stress is: 0.04998095856790095
# The inherent dimensionality for label 89 is:  12 Stress is: 0.04997362307656529
# The inherent dimensionality for label 90 is:  20 Stress is: 0.04999380683863152
# The inherent dimensionality for label 91 is:  14 Stress is: 0.049932291353495285
# The inherent dimensionality for label 92 is:  22 Stress is: 0.04998097067612908
# The inherent dimensionality for label 93 is:  20 Stress is: 0.04998136290667048
# The inherent dimensionality for label 94 is:  30 Stress is: 0.04998635363869995
# The inherent dimensionality for label 95 is:  13 Stress is: 0.049961977084972194
# The inherent dimensionality for label 96 is:  18 Stress is: 0.049997011045002
# The inherent dimensionality for label 97 is:  12 Stress is: 0.04994382046584273
# The inherent dimensionality for label 98 is:  17 Stress is: 0.049994630275131235
# The inherent dimensionality for label 99 is:  12 Stress is: 0.04999494833943734
# The inherent dimensionality for label 100 is:  16 Stress is: 0.04995709209067315
# Data saved successfully at  /content/drive/MyDrive/CSE515_Phase3/task0/inherent_dimensionality_for_labels_info_json_file_path.json

# %%
# Code to calculate inherent dimensionality for input label
query_label = input("Enter any label to check the inherent dimensionality")

#Retrieving imageIds for the input label
imageids = labelsWithImages[query_label]

# Retrieving layer 3 for images under the input label
values = [fd_data[str(image_id)]['layer_3'] for image_id in imageids if str(image_id) in fd_data]
values = np.array(values)

# Applying MDS to find the inherent dimensionality for the input label
reduced_features, best_stress, best_iteration, inherent_dimensionality = MDS_scratch(values)

# Displaying the inherent dimensionality and features at the inherent dimensionality along with the stress at inherent dimensionality for the label and shape of the features in the reduced inherent dimensionality
print("The inherent dimensionality for label", query_label, "is: ", inherent_dimensionality, "Stress is:", best_stress, "reduced features are: ", reduced_features)
print("The shape of features at the inherent dimensionality is ", reduced_features.shape)
# Out:
# Enter any label to check the inherent dimensionality39
# The inherent dimensionality for label 39 is:  1 Stress is: 0.5687719933219711 reduced features are:  [[-6.67817634e-02  7.22349884e-02  6.11608371e-02  7.28054967e-02
#    4.46713117e-02 -2.39850366e-02  7.43768526e-02 -2.77798946e-02
#   -3.35790555e-02  2.50124106e-02  5.11170190e-02  1.10453348e-02
#    6.26379896e-02 -1.07418214e-01 -8.14807776e-03  1.18954112e-02
#    7.58910198e-04  1.31861637e-03  4.66593277e-03 -4.35772669e-04
#   -5.07868081e-03]
#  [ 2.53660142e-02 -3.21956620e-04  8.73952197e-03 -1.03851583e-01
#    4.19899630e-02  3.10743729e-02  3.84347681e-02 -2.61882052e-02
#   -1.56955549e-02  6.53339417e-02 -8.08655055e-02 -3.69019368e-02
#    3.01026726e-02  4.72780188e-02  7.93402856e-02  2.74781242e-03
#    6.93270060e-02 -7.83247961e-02  8.13084524e-02  5.57350262e-02
#   -4.12234689e-02]
#  [-9.75903167e-02 -3.89100593e-02  1.85886360e-02 -7.85034221e-02
#   -2.55189497e-02  3.70022091e-02  4.79350956e-02  4.97613344e-02
#    7.27188069e-03  6.89003912e-02  1.54123624e-02  4.22253619e-02
#    3.19761264e-02  6.80984354e-03 -5.44215395e-03 -1.83785981e-02
#    1.03611013e-01 -1.26314036e-02 -9.75587237e-02  3.60424796e-02
#    1.74623805e-03]
#  [-3.12720900e-02  2.76273901e-02 -1.24325164e-01  2.59416813e-02
#   -4.51219299e-03  4.05315193e-02  5.81818817e-02  1.10738375e-01
#   -4.12333026e-02 -3.17762252e-02 -3.89584069e-02  1.55975287e-03
#   -2.11893660e-02  4.05756245e-02 -1.14021322e-02  4.71999039e-02
#    3.88523074e-02  1.70091938e-02 -5.04143836e-03  5.07489523e-02
#   -7.36621537e-02]
#  [ 2.41458883e-02  4.94839051e-02  5.00387873e-02  8.77893263e-03
#    5.58757752e-02  4.49942363e-03  2.45694702e-02 -6.49480225e-02
#    3.28864400e-02  6.42228410e-02 -3.68007891e-02 -6.24485973e-02
#   -3.97901060e-03 -8.85914585e-04  1.89745666e-02 -4.49504054e-02
#    4.76767381e-02  4.12064685e-02 -5.61332606e-02 -6.48511027e-02
#   -1.10070519e-01]
#  [ 5.09206635e-02 -1.11920228e-02  7.06513238e-02 -4.71439920e-02
#   -3.28215744e-03  2.45294700e-03  3.83738580e-03  4.16536593e-02
#   -9.21142615e-02  4.75732170e-02 -3.46278011e-02 -1.42718932e-02
#    4.45073227e-02 -7.18177272e-03 -1.01054628e-01  1.35752671e-02
#   -3.05274277e-02 -3.80900346e-03  1.04159135e-01 -5.05600897e-02
#    2.27750198e-02]
#  [ 5.12456087e-02  7.22387259e-02  9.72791184e-02  2.92004697e-02
#   -2.21988807e-02 -6.66453451e-02  8.78809731e-02  3.38341064e-02
#    6.64047783e-02 -8.30485692e-03  8.40652257e-02  6.60903266e-04
#    4.27641187e-02  6.62052901e-02 -9.05159066e-03  3.91298664e-02
#    7.50874927e-02 -2.69141946e-02  3.42228944e-02  4.37358635e-03
#    8.72526390e-02]
#  [-9.31922780e-02 -2.45459107e-02 -9.83721805e-04  6.24612512e-03
#    2.64896508e-02 -3.49443540e-02 -7.12549551e-02  9.74997325e-03
#   -1.08452930e-01 -6.65948553e-02 -1.27151378e-01  5.24180482e-02
#    8.45383004e-03  7.56763103e-03 -6.41113359e-03 -6.49359646e-02
#   -5.54673645e-02  2.85776777e-02 -2.76168038e-02  1.90790668e-02
#   -3.39182721e-02]
#  [-4.06097548e-02  6.28293691e-02  3.88548340e-02  7.36728710e-03
#    3.73380369e-02 -1.71537678e-02 -9.34115402e-02  5.64580965e-02
#    3.94162679e-02  8.40389448e-02 -1.01180755e-02  9.54797734e-02
#   -1.69945933e-03  3.10640383e-03 -8.45415330e-02 -1.96847599e-02
#   -5.08866296e-02 -2.41644728e-02 -6.93166145e-02  6.17361720e-02
#    2.68827246e-02]
#  [-3.98188865e-02  4.04456205e-02  8.60623331e-02  3.09045202e-02
#   -1.26679509e-01 -9.35513884e-03 -1.01297433e-02  7.06792875e-03
#    4.72761187e-02  2.23826758e-02 -5.36150304e-03 -4.27960342e-02
#   -3.34874738e-02  6.55976080e-02 -8.13317468e-02 -5.74608814e-02
#   -9.23967546e-02  9.49163315e-02 -7.13815124e-03  2.60758427e-02
#   -7.31029168e-03]
#  [ 4.02641732e-02 -7.40773804e-03  9.73357144e-02  4.07868008e-02
#    7.76536015e-02 -3.46125356e-02  4.79187023e-02 -4.20360007e-03
#   -5.81117447e-02 -4.65124741e-02  3.85306720e-02 -1.04421614e-02
#   -9.72121649e-02  6.77366390e-02 -1.79676462e-02  4.66864605e-02
#   -1.79411195e-02 -7.00648401e-02 -3.07051511e-02 -2.34568760e-02
#   -4.71017000e-02]
#  [ 3.54081066e-02 -1.10448895e-03 -5.55405725e-02 -9.23690546e-02
#   -2.17082452e-02  3.65310664e-02 -7.20280090e-02 -1.62391671e-02
#    1.48733865e-02  4.25082642e-02  8.20345319e-02  1.78613556e-02
#    1.88934629e-02  4.97694756e-02  1.56521285e-02 -3.30491773e-03
#   -1.54132586e-02 -5.43722501e-02 -1.68354216e-02 -1.10173388e-01
#    4.39202434e-02]
#  [-4.09503960e-02 -1.00934313e-01 -4.91284415e-02  1.67902407e-02
#    5.49885558e-02  4.36669824e-02  1.10313524e-03 -3.33509168e-02
#    3.96994353e-02  7.16410473e-02 -1.46889955e-02  1.93025125e-02
#    6.63378455e-02 -5.47224244e-02 -7.86268444e-03  7.01466712e-02
#   -3.41395172e-02  2.11653991e-02 -2.55100949e-02 -4.36873716e-02
#   -3.91505882e-02]
#  [-1.01549645e-02 -2.32969038e-02  7.16463303e-02 -6.39250003e-02
#   -4.32187545e-02 -1.74347694e-02  9.84036984e-03  3.88688208e-02
#    1.29397005e-02 -8.94503119e-03  5.67598086e-02 -6.53784867e-02
#    3.88264922e-02 -1.29615616e-01 -1.07210153e-02  1.27889126e-02
#   -4.16189773e-02 -4.13240162e-02 -3.13411415e-02 -1.12293108e-01
#   -6.72708609e-02]
#  [ 1.21854948e-01 -1.31173672e-02  1.96100937e-02  3.74733360e-02
#   -5.44189114e-02 -1.81556927e-02 -3.58216633e-02  2.83509898e-02
#   -1.27345172e-02  8.18355830e-03  3.15168326e-02  1.19847813e-02
#    4.50746443e-02 -9.10240877e-02  9.20703197e-02 -6.22848666e-02
#    4.61564082e-02  6.07696775e-02 -6.78370049e-02 -2.07400024e-02
#    5.69873523e-02]
#  [ 1.17082598e-02 -1.66540500e-02 -1.14735095e-02  6.32165486e-02
#    3.29053150e-02  8.13180324e-02  4.21531098e-02 -5.87492209e-02
#    1.31312261e-02  3.28200568e-02  5.50789958e-02  9.48464322e-02
#   -3.42883519e-02  8.30723261e-02 -1.55646545e-03 -8.70657578e-02
#    1.47305103e-02  5.53289282e-02  1.29054943e-02 -5.47196417e-02
#    8.96737814e-02]
#  [ 8.11969195e-03 -5.25378870e-02 -4.53885617e-02  4.51825053e-02
#    3.13696536e-02  4.29985967e-02  9.73439415e-02 -8.97828126e-03
#   -9.70625029e-03 -4.25107968e-02  8.65831507e-02 -4.49675857e-02
#    4.46258326e-02 -4.57523153e-03  1.09996006e-02 -6.32245608e-02
#   -7.95931822e-02 -3.32856847e-03 -4.36893128e-02  8.46273587e-03
#   -2.70121763e-02]
#  [-2.44090645e-03  8.78178367e-02 -6.05348232e-02  4.26122904e-02
#   -2.11370090e-02 -1.72823387e-02 -1.20459791e-02  3.62660463e-02
#   -3.17654096e-02 -2.30630463e-02  4.64673075e-02 -2.06164523e-02
#   -6.10122825e-02 -6.82790562e-02 -4.34803181e-02 -1.99512338e-02
#    4.29532063e-03 -9.52480788e-02 -7.15218613e-02  1.81110761e-02
#   -4.53041228e-02]
#  [ 6.02700528e-02  4.61388639e-03 -2.07134179e-02 -6.45885007e-02
#    7.03000334e-02  5.53490121e-02  2.19402359e-02  1.37369688e-02
#   -1.13555749e-02 -5.42255948e-02 -4.63932336e-02 -3.45985673e-02
#   -8.59016592e-02  1.63318395e-02  7.68817913e-02 -7.08050029e-02
#   -6.61971687e-02 -3.70986285e-02 -1.97910978e-02  6.04187978e-02
#    1.66953405e-04]
#  [ 1.02117146e-02  4.40927720e-03 -7.46583308e-02 -3.50212987e-02
#    5.24491253e-02 -7.56782399e-02  8.15501539e-02 -3.97872773e-02
#    2.26103891e-02 -5.39033061e-02 -5.05344202e-03  2.12268849e-02
#    6.83283757e-02  1.61248795e-02 -3.75537182e-02 -2.18674623e-02
#    6.31370251e-02 -1.91246898e-02 -6.42274904e-02 -4.24870313e-02
#    1.19247047e-01]
#  [-4.74305666e-02  3.25767995e-02 -1.09643572e-01 -8.41323968e-02
#   -2.55139815e-02 -4.44098709e-02  5.78464119e-02  3.29829742e-02
#    8.11766448e-03 -2.93690658e-02 -1.02113261e-02 -4.07714147e-02
#    1.51375221e-03 -5.40253254e-02  1.69865576e-02 -9.04380966e-02
#   -2.83680359e-02  4.55192076e-02  1.14628352e-01 -4.47093616e-02
#   -3.01128805e-02]
#  [-2.92969121e-02  2.03570341e-02 -2.27415613e-02 -6.78385847e-02
#    3.58848610e-03  5.43495043e-02 -3.22147169e-02 -6.56195672e-02
#   -1.11270779e-01 -7.08682594e-03 -2.65119346e-02 -6.76334502e-02
#   -9.28753662e-02 -1.25669842e-02  8.13151225e-04  4.82150667e-02
#    1.20246780e-02  2.38755507e-02 -9.98039701e-03  1.01000390e-01
#    2.96207043e-02]
#  [-9.81895135e-02 -2.41583709e-02  2.71364389e-02  1.45582743e-04
#   -3.53795380e-02 -1.69000669e-02  1.25261413e-03 -5.28597524e-02
#   -3.78440578e-02 -4.33869104e-02  5.81072354e-02 -3.23500996e-02
#    3.04798095e-02  5.81981429e-02  8.78088325e-02 -6.90343677e-02
#    4.12119823e-02  1.63050864e-02 -5.51116507e-02 -8.68109838e-02
#    1.05375891e-01]
#  [-2.30237009e-03 -1.01000649e-04  2.04338700e-02  2.40017551e-03
#   -3.08295782e-02 -5.31319523e-02 -9.00727461e-02 -8.14834921e-02
#    9.07681550e-02 -7.24678259e-02 -8.07246911e-03 -6.16853049e-03
#    3.46348685e-02  1.73860598e-02 -1.45038217e-02  2.94943252e-02
#   -3.56377661e-02 -1.26799759e-01  1.55294169e-02  2.93623498e-02
#   -8.31881468e-03]
#  [ 2.24543344e-02 -2.56014947e-02 -4.46079718e-02  7.59327562e-03
#    4.90335147e-02 -2.02290115e-02 -9.17597896e-02  4.92567854e-02
#   -2.93863134e-02  4.55536265e-02 -4.04312186e-02 -1.01476037e-01
#    7.66646346e-02  3.51984382e-02 -3.49245217e-02  4.66215801e-02
#    4.67878839e-02  1.95185994e-02 -4.54631540e-02  3.24767570e-02
#    1.84934725e-02]
#  [-1.27388492e-02 -6.94575299e-03 -5.27052469e-02  4.36138834e-02
#   -1.48867606e-02  7.30947403e-02 -1.23359900e-02 -1.36323029e-02
#   -1.26736554e-02 -2.65270012e-02  2.51349786e-02 -2.72284842e-02
#   -2.05810243e-03  3.76404010e-02  5.15811428e-02  1.00893714e-01
#   -5.82997444e-02 -7.07473502e-03 -2.95902837e-02 -7.08342504e-02
#    1.42439128e-01]
#  [ 2.20117246e-02  6.88113932e-02 -6.69356643e-02  4.43681273e-02
#   -6.39104482e-02 -9.53889373e-02  1.74548927e-02 -6.96116654e-02
#   -2.45074431e-02  6.85464100e-02 -6.93031327e-02  3.73367917e-03
#    8.98669270e-04  2.25860234e-02 -1.46120073e-03 -8.27146574e-03
#   -5.64216514e-02  1.74272010e-02  2.91438056e-03  1.49053471e-02
#   -7.78629345e-02]
#  [ 3.84706473e-03 -7.12766334e-02  1.05611064e-02  6.83832091e-03
#    9.89116141e-03 -1.18267296e-01  1.91967394e-02  7.62134086e-02
#   -9.65211914e-04  6.25891546e-02  5.93018624e-02  1.26482731e-01
#   -5.84371812e-02 -1.38805838e-03  3.65178731e-02  2.05119421e-02
#   -7.17896401e-02 -1.72629025e-03  2.16514167e-02  1.20651150e-02
#    3.75107393e-02]
#  [ 9.36316882e-02 -1.45444780e-02  5.42436202e-02 -7.60302713e-03
#   -4.86374218e-02  3.59277969e-03 -7.87698321e-02  8.19779055e-02
#    5.59721385e-02 -9.83034201e-02 -9.08387052e-02  9.12687581e-02
#    2.42131192e-02  3.06076941e-02 -8.56889225e-03 -4.89093314e-02
#   -1.95500265e-02 -2.68929080e-03 -4.21078579e-02 -6.20010368e-02
#   -6.96517781e-02]
#  [-7.37779408e-02 -5.91439628e-02 -3.50882827e-02 -2.57729057e-02
#   -3.14752854e-02 -2.60458815e-02  6.02011073e-03  4.44414321e-02
#    8.51892810e-02  1.89745306e-02  2.39340255e-02 -8.50047867e-02
#    1.98065396e-02  1.47917156e-02  7.58063143e-02  5.25332927e-02
#   -2.94554268e-03  8.10501684e-02 -4.53399708e-02  6.77948302e-02
#   -2.82279464e-02]
#  [ 5.56001254e-03  6.15164030e-02 -2.49649485e-03 -1.48215422e-02
#    3.79646566e-02 -2.77228544e-02 -9.05998237e-03  6.44882520e-02
#    1.11550422e-02 -3.15039241e-02  7.10119309e-02  7.24498035e-02
#   -5.96389900e-02  6.40643633e-03  3.99689814e-02  7.46710465e-02
#    5.30762675e-02  9.32002557e-02  1.96206107e-02 -1.26745007e-01
#    2.64273074e-02]
#  [ 8.79908265e-02 -5.18020756e-03 -2.75404335e-02  7.94719131e-02
#   -4.04110156e-02  8.89059280e-03 -6.88602222e-02 -7.01469532e-02
#    3.06898609e-02  4.72821114e-02  1.37947157e-02 -1.49327469e-03
#   -7.41492293e-02 -1.07511293e-02  1.35963159e-02  4.23812387e-02
#    8.95733080e-02 -2.34913560e-03  7.15830314e-02 -1.67972566e-02
#   -2.76282591e-02]
#  [ 1.69532834e-02 -9.50465786e-02 -2.11108944e-04  8.93678467e-02
#    1.66334104e-02 -3.24485064e-02 -6.67751267e-03  5.18154765e-02
#   -3.27394322e-04  2.93809446e-02 -5.57675603e-02 -5.58816394e-02
#   -1.00987739e-01 -8.05049029e-02 -1.97997593e-02 -3.59342644e-02
#    5.56077162e-02  8.09100548e-03  3.82845745e-03 -2.51500573e-02
#    5.84113809e-02]
#  [-4.91911270e-03  1.89580741e-02  1.09667332e-01 -3.79995834e-02
#    8.05156111e-02 -6.79070543e-02 -8.23070837e-02 -2.92478755e-02
#    6.58391323e-02 -5.49767594e-02  2.34027598e-03  4.14942253e-02
#   -2.81567081e-02 -7.35581261e-02  5.82745254e-04 -9.63757111e-03
#   -6.72065812e-02  6.33679483e-02  2.39128742e-02  5.92592228e-02
#    8.97885052e-03]
#  [-5.91804031e-02  2.37979825e-03  1.04289725e-01  5.04906298e-03
#   -5.10631081e-02  3.47775410e-02  3.67234131e-02 -6.43048845e-02
#    2.24344747e-02 -8.52805971e-02 -4.69338691e-02  9.56510236e-02
#   -9.07779009e-02 -2.90862090e-02 -5.09608748e-02  4.97687685e-02
#    2.03040971e-02 -3.53298987e-02  1.20009687e-02 -2.98067041e-02
#   -3.61766597e-02]
#  [-5.15507008e-02  3.17868875e-02  2.54209424e-04  7.49377038e-02
#    6.43899297e-02 -9.37577781e-03  6.91408887e-03 -3.37401260e-03
#    7.55583683e-02  1.19215599e-02 -2.12471437e-02 -4.28356151e-02
#    1.07030001e-02  4.73836367e-02  4.99177200e-03  4.12977787e-03
#   -2.41609141e-03 -6.54002285e-02  8.64754524e-02 -9.27493877e-02
#   -1.47929864e-02]
#  [ 5.65107057e-02  6.32978883e-02  3.31021511e-02 -2.90739227e-02
#    8.53374674e-03  5.97409152e-02 -1.14183137e-02 -5.23805093e-02
#   -3.43865032e-02 -4.73920735e-02 -7.16908713e-02  9.18855571e-04
#    5.76825822e-02  1.11321276e-02 -1.43676225e-02  7.15709344e-02
#   -5.85533895e-02  6.34763056e-02  3.39811231e-03  1.05118722e-01
#   -1.02394569e-02]
#  [ 3.69326416e-02 -6.77856551e-02 -3.07982679e-02  1.53713458e-02
#   -9.55416511e-03 -5.43147714e-02 -6.22122432e-02 -3.55543063e-02
#   -3.24531492e-02  3.81774248e-02  8.63310164e-02  2.57905791e-02
#    1.88244448e-02  3.94087008e-02 -7.41087777e-02 -6.43164765e-02
#    4.37539115e-02  3.28151417e-02  8.61215439e-02  3.54351803e-02
#   -6.51575238e-02]
#  [ 5.50682384e-02 -8.04796943e-03 -1.46677237e-02 -4.69489077e-02
#   -5.35426275e-02  2.16001495e-02  3.70453692e-02 -2.12140518e-02
#    7.86158119e-02  3.76648887e-02 -1.00891554e-01  5.85184475e-03
#   -4.07030345e-02 -3.13783634e-02 -1.00998518e-01  2.30041093e-02
#   -2.57443855e-02  1.15496265e-02 -1.46077780e-03  7.42547795e-02
#    4.25396889e-02]
#  [-5.80329125e-03  3.61935515e-02 -2.85886776e-02  1.19837250e-02
#    7.58915044e-02  9.18545308e-02 -3.29202365e-02  3.79454955e-02
#    2.03523270e-02 -5.64651737e-02  7.17462617e-02 -5.01499703e-02
#    2.12952542e-02 -5.00780013e-02 -6.08575849e-02 -1.58097980e-02
#    5.30874010e-02  4.15788857e-03  7.16451355e-02  1.87667379e-02
#   -9.30365208e-03]
#  [ 1.46354153e-02 -1.66871700e-02 -6.88924801e-02 -1.48776221e-01
#   -1.30614163e-02  3.76615330e-02  1.89253641e-02 -8.43786155e-02
#   -6.52900938e-02 -2.60050878e-02 -1.82617237e-02 -3.79487338e-02
#    3.41234175e-02  4.60721783e-02  9.77293499e-03  1.19165828e-01
#    4.82292455e-02  4.38515286e-03 -2.58904418e-02  9.95022181e-02
#   -8.91230623e-02]
#  [-4.03350923e-02  2.00996319e-02  5.71582019e-03  3.33330624e-02
#   -7.95244416e-02  1.04559974e-01 -3.14318115e-02  7.16052951e-02
#   -2.63977827e-02  7.55839493e-02  9.84263523e-03  1.55090360e-02
#    1.04865082e-02 -1.19361750e-02  1.20463447e-01 -1.22346685e-02
#   -5.44190192e-02 -3.83257806e-02  5.82100920e-02  2.41297199e-02
#   -3.70479652e-03]
#  [-6.77494855e-03 -9.31364889e-02 -3.77077739e-02  1.06589683e-01
#   -5.20086456e-02  1.58427768e-02  6.62872910e-02 -1.31807492e-02
#   -5.09508947e-02 -5.36910977e-02 -8.93020503e-03  3.36020745e-02
#    4.26987068e-02 -1.80115422e-02  5.42676567e-02 -3.86314783e-02
#    3.82440509e-02 -5.89313698e-02  6.04263491e-02  6.41533241e-02
#    4.89544245e-02]]
# The shape of features at the inherent dimensionality is  (43, 21)
